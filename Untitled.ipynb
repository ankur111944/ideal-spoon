# %%
import pandas as pd

# %%
books = pd.read_csv("google_books_dataset.csv")

# %%
books.head()
# Out:
#    Unnamed: 0                                         title  \
# 0           0          Sammy Keyes and the Art of Deception
# 1           1                                Inward Journey
# 2           2                      The Boston Directory ...
# 3           3  Bring Your Own Devices (BYOD) Survival Guide
# 4           4                                Enterprise 2.0
#
#                     authors language                categories  averageRating  \
# 0  ['Wendelin Van Draanen']       en      ['Juvenile Fiction']            4.0
# 1                       NaN       en               ['Medical']            NaN
# 2                       NaN       en                ['Boston']            NaN
# 3         ['Jessica Keyes']       en  ['Business & Economics']            NaN
# 4         ['Jessica Keyes']       en  ['Business & Economics']            NaN
#
#   maturityRating                      publisher publishedDate  pageCount
# ...

# %%
books.columns
# Out:
# Index(['Unnamed: 0', 'title', 'authors', 'language', 'categories',
#        'averageRating', 'maturityRating', 'publisher', 'publishedDate',
#        'pageCount'],
#       dtype='object')

# %%
books = books.drop(['Unnamed: 0' , 'language','maturityRating' ,  'pageCount'] , axis = 1)

# %%
books
# Out:
#                                                   title  \
# 0                  Sammy Keyes and the Art of Deception
# 1                                        Inward Journey
# 2                              The Boston Directory ...
# 3          Bring Your Own Devices (BYOD) Survival Guide
# 4                                        Enterprise 2.0
# 5      The CIO's Guide to Oracle Products and Solutions
# 6                Implementing the IT Balanced Scorecard
# 7     Implementing the Project Management Balanced S...
# 8                           Social Software Engineering
# 9         Classes on Modern Poets and the Art of Poetry
# 10                            Population Health Science
# 11    Retelling the Nicaraguan Revolution as a Diony...
# 12                                 Flowers for Algernon
# 13            Handbook of Applied Developmental Science
# 14    Wade Keyes' introductory lecture to the Montgo...
# 15           The Journal of the Iowa Academy of Science
# ...

# %%
books.categories.value_counts()
# Out:
# ['Computers']                                      90
# ['Juvenile Fiction']                               61
# ['Fiction']                                        41
# ['History']                                        38
# ['Business & Economics']                           32
# ['Law']                                            26
# ['Education']                                      22
# ['Geology']                                        21
# ['Biography & Autobiography']                      21
# ['Social Science']                                 18
# ['Religion']                                       18
# ['Performing Arts']                                18
# ['Literary Criticism']                             17
# ['Psychology']                                     17
# ['Medical']                                        15
# ['Technology & Engineering']                       14
# ['Science']                                        14
# ...
